# %%
import pandas as pd
import json
from nba_api.stats.static import teams
from nba_api.stats.endpoints import leaguedashteamptshot

# %% [markdown]
# ## Getting All team stats 2021-2022 Season

# %%
from nba_api.stats.endpoints import leaguedashteamptshot
df = leaguedashteamptshot.LeagueDashTeamPtShot(per_mode_simple = 'PerGame', season = '2021-22', season_type_all_star = 'Regular Season').get_data_frames()[0]
df.head()
# Out:
#       TEAM_ID               TEAM_NAME TEAM_ABBREVIATION  GP   G  \
# 0  1610612763       Memphis Grizzlies               MEM  81  81
# 1  1610612759       San Antonio Spurs               SAS  82  82
# 2  1610612766       Charlotte Hornets               CHA  81  81
# 3  1610612761         Toronto Raptors               TOR  82  82
# 4  1610612750  Minnesota Timberwolves               MIN  82  82
#
#    FGA_FREQUENCY    FGM    FGA  FG_PCT  EFG_PCT  FG2A_FREQUENCY   FG2M   FG2A  \
# 0            1.0  43.49  94.32   0.461    0.522           0.654  31.95  61.64
# 1            1.0  43.24  92.67   0.467    0.528           0.655  31.96  60.67
# 2            1.0  42.78  91.44   0.468    0.544           0.582  28.80  53.23
# 3            1.0  40.63  91.32   0.445    0.510           0.625  28.70  57.07
# 4            1.0  41.59  90.95   0.457    0.538           0.546  26.82  49.65
#
#    FG2_PCT  FG3A_FREQUENCY   FG3M   FG3A  FG3_PCT
# 0    0.518           0.346  11.54  32.68    0.353
# ...

# %%
df.to_csv(r'C:\Users\16606\team_shooting.csv', index=False)
